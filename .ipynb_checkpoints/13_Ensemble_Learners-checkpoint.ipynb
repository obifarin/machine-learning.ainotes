# %% [markdown]
# ***
#
# # Ensemble Learning
#
# Author: Olatomiwa Bifarin. <br>
# PhD Candidate Biochemistry and Molecular Biology <br>
# @ The University of Georgia
#
# _This is a draft copy, a work in progress_

# %% [markdown]
# ## Notebook Content
#
# 1. [Description](#1) <br>
# 2. [Voting Classifiers](#2) <br>
# 3. [Bagging/Pasting](#3) <br>
# 4. [Random Forests](#4) <br>
# 5. [AdaBoost](#5)

# %%
# More sharp and legible graphics
# %config InlineBackend.figure_format = 'retina'
# numerical python
import numpy as np
# decision tree classifier
from sklearn.tree import DecisionTreeClassifier
# import pandas
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Description
# <a id="1"></a>

# %% [markdown]
# One of the exicting things I found about learning machine intelligence is it's amenabilities to visible analogies, more so that it mimicks intelligence itself. Once again, ensemble learning affords us such comfort. The analogy here is the wisdom of the crowd - rather than rely on a single expert, why not gather a bunch and make them vote? If you are thinking Wikipedia, Quora, Stack Exchange, then we are riding the same car, we are on the same lane.

# %% [markdown]
# ## 2. Voting Classifiers
# <a id="2"></a>

# %% [markdown]
# <img align='center' src='datasets/random_forest/voting_classifier.png' width=80%/>

# %%
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
iris = datasets.load_iris()
print('data shape is {}'.format(iris.data.shape))
print('class shape is {}'.format(iris.target.shape))
# Out:
# data shape is (150, 4)
# class shape is (150,)

# %%
X = iris.data[:, :2] # first two :2
y = iris.target # Label

# %%
import matplotlib.pyplot as plt
iris = datasets.load_iris()
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000',  '#00FF00', '#0000FF'])

K = 3
x = X[-1]

fig, ax = plt.subplots(figsize=(4,4))
for i, iris_class in enumerate(['Iris Setosa', 'Iris Versicolor', 'Iris Virginica']):
    idx = y==i
    ax.scatter(X[idx,0], X[idx,1], 
               c=cmap_bold.colors[i], edgecolor='k', 
               s=40, label=iris_class);
ax.set(xlabel='sepal length (cm)', ylabel='sepal width (cm)')
ax.legend();

# %% [markdown]
# _Machine Learning Algorithms + Voting classifiers_

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier

log_clf = LogisticRegression(random_state=42)
dt_clf = DecisionTreeClassifier(random_state=42)
nb_clf = GaussianNB()
knn_clf = neighbors.KNeighborsClassifier(n_neighbors=5)

vclf = VotingClassifier(estimators=[('lr', log_clf), 
                                    ('dt', dt_clf), 
                                    ('knn', knn_clf)], voting='hard')

# %% [markdown]
# _Decision boundaries_

# %%
def decision_boundary(model, title): 
    ''' model = machine learning algorithm
        title = name of ML algo...'''
    model.fit(X, y)

    # step size in mesh
    h = 0.02

    # decision boundary
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                        np.arange(y_min, y_max, h))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    
    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.figure(figsize=(4,4))
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
    
    # Plot points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold);
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title(title)

    plt.show()

# %%
for clf, label in zip([log_clf, dt_clf, knn_clf, vclf], 
                      ['Logistic Regression', 
                       'Decision Trees', 
                       'k-NN', 'Voting']):
    scores = cross_val_score(clf, X, y, scoring='accuracy', cv=5)
    decision_boundary(clf, print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label)));
# Out:
# Accuracy: 0.77 (+/- 0.07) [Logistic Regression]
# Accuracy: 0.71 (+/- 0.03) [Decision Trees]
# Accuracy: 0.77 (+/- 0.06) [k-NN]
# Accuracy: 0.76 (+/- 0.04) [Voting]

# %% [markdown]
# ## 3. Bagging/Pasting
# <a id="3"></a>

# %% [markdown]
# <img align='center' src='datasets/random_forest/bagging.png' width=80%/>

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

bag_clf = BaggingClassifier(LogisticRegression(random_state=42), 
                            bootstrap=True)
paste_clf = BaggingClassifier(LogisticRegression(random_state=42), 
                            bootstrap=False)

# %%
for clf, label in zip([log_clf, bag_clf, paste_clf], 
                      ['Logistic Regression', 
                       'Bagging', 'Pasting']):
    scores = cross_val_score(clf, X, y, 
                             scoring='accuracy', 
                             cv=5)
    decision_boundary(clf, print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label)));
# Out:
# Accuracy: 0.77 (+/- 0.07) [Logistic Regression]
# Accuracy: 0.76 (+/- 0.06) [Bagging]
# Accuracy: 0.77 (+/- 0.07) [Pasting]

# %% [markdown]
# ## 4. Random Forest
# <a id="4"></a>

# %% [markdown]
# <img align='center' src='datasets/random_forest/random_forest.png' width=70%/>

# %% [markdown]
# ## 5. AdaBoost
# <a id="5"></a>

# %% [markdown]
# ## 6. References and Resources
# <a id="6"></a>
#
# - __[Scikit Learn, Ensemble method documentation](https://scikit-learn.org/stable/modules/ensemble.html)__
# - __[StatQuest with Josh Starmer, AdaBoost Clearly Explained](https://www.youtube.com/watch?v=LsK-xG1cLYA&t=144s)__
# - Include all original papers on methods

# %% [markdown]
# https://www.hackerearth.com/practice/machine-learning/machine-learning-algorithms/ml-decision-tree/tutorial/
